# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
endereco
# Out:
#    enderecosk          estado
# 0           1          Hawaii
# 1           2          Oregon
# 2           3        Delaware
# 3           4          Kansas
# 4           6            Ohio
# 5           7   West Virginia
# 6           8           Idaho
# 7          10         Vermont
# 8          11        Nebraska
# 9          12       Minnesota
# 10         14           Texas
# 11         15        Missouri
# 12         17        Oklahoma
# 13         18         Florida
# 14         19        Colorado
# 15         20        Kentucky
# 16         21         Georgia
# 17         22     Mississippi
# 18         23    Rhode Island
# 19         25       Louisiana
# 20         28  South Carolina
# 21         29       Wisconsin
# 22         32         Indiana
# 23         33      New Mexico
# 24         35    North Dakota
# 25         36        Illinois
# 26         38  North Carolina
# 27         39        Maryland
# 28         40         Wyoming
# 29         41         Montana
# ...

# %%
fato_avaliacao = pd.read_csv('data/CSVs/avaliacao.csv')
calendario = pd.read_csv('data/CSVs/calendario.csv')
endereco = pd.read_csv('data/CSVs/endereco.csv')
filme = pd.read_csv('data/CSVs/filme.csv')
produtora = pd.read_csv('data/CSVs/produtora.csv')
fato_receita = pd.read_csv('data/CSVs/receita.csv')
usuario = pd.read_csv('data/CSVs/usuario.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 endereco = pd.read_csv('data/CSVs/endereco.csv')
#       4 filme = pd.read_csv('data/CSVs/filme.csv')
# ----> 5 produtora = pd.read_csv('data/CSVs/produtora.csv')
#       6 fato_receita = pd.read_csv('data/CSVs/receita.csv')
#       7 usuario = pd.read_csv('data/CSVs/usuario.csv')
#
# ...

# %%
movies
# Out:
#                                   name  duration  release_year  rating  \
# 0                             Harakiri       133          1964     8.6
# 1                           The Matrix       136          1999     8.7
# 2   Star Wars: Episode IV - A New Hope       121          1977     8.6
# 3                          City Lights        87          1931     8.5
# 4      One Flew Over the Cuckoo's Nest       133          1975     8.7
# ..                                 ...       ...           ...     ...
# 95      Jumanji: Welcome to the Jungle       119          2017     6.9
# 96                       Donnie Brasco       127          1997     7.7
# 97                  Mad Max: Fury Road       120          2015     8.1
# 98                     Despicable Me 2        98          2013     7.3
# 99                        Peacock King        86          1988     6.1
#
#     rating_count                          genres  \
# 0          83304                [drama, mystery]
# ...
