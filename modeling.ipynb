# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
companies = pd.read_parquet('data/companies.parquet')
genres = pd.read_parquet('data/genres.parquet')
movies = pd.read_parquet('data/movies.parquet')
people = pd.read_parquet('data/people.parquet')

# %%
movies
# Out:
#                                   name  duration  release_year  rating  \
# 0                             Harakiri       133          1964     8.6
# 1                           The Matrix       136          1999     8.7
# 2   Star Wars: Episode IV - A New Hope       121          1977     8.6
# 3                          City Lights        87          1931     8.5
# 4      One Flew Over the Cuckoo's Nest       133          1975     8.7
# ..                                 ...       ...           ...     ...
# 95      Jumanji: Welcome to the Jungle       119          2017     6.9
# 96                       Donnie Brasco       127          1997     7.7
# 97                  Mad Max: Fury Road       120          2015     8.1
# 98                     Despicable Me 2        98          2013     7.3
# 99                        Peacock King        86          1988     6.1
#
#     rating_count                          genres  \
# 0          83304                [drama, mystery]
# 1        2189795                [action, sci-fi]
# 2        1533237    [action, adventure, fantasy]
# 3         209894        [comedy, drama, romance]
# 4        1132295                         [drama]
# ..           ...                             ...
# 95        488812     [action, adventure, comedy]
# 96        349055       [biography, crime, drama]
# 97       1182678     [action, adventure, sci-fi]
# 98        450010  [animation, adventure, comedy]
# 99           487    [action, adventure, fantasy]
#
#                  production_companies  \
# 0                         [co0007001]
# 1   [co0002663, co0108864, co0060075]
# 2              [co0071326, co0000756]
# 3                         [co0028083]
# 4              [co0066949, co0046377]
# ..                                ...
# 95  [co0050868, co0332017, co0023815]
# 96  [co0033437, co0038108, co0013696]
# 97  [co0002663, co0227121, co0351258]
# 98             [co0005073, co0221986]
# 99             [co0015592, co0064457]
#
#                                               img_url               directors  \
# 0   https://m.media-amazon.com/images/M/MV5BZThiZj...             [nm0462030]
# 1   https://m.media-amazon.com/images/M/MV5BN2NmN2...  [nm0905154, nm0905152]
# 2   https://m.media-amazon.com/images/M/MV5BOGUwMD...             [nm0000184]
# 3   https://m.media-amazon.com/images/M/MV5BYmMwZD...             [nm0000122]
# 4   https://m.media-amazon.com/images/M/MV5BYjBkMj...             [nm0001232]
# ..                                                ...                     ...
# 95  https://m.media-amazon.com/images/M/MV5BZjI5Mz...             [nm0440458]
# 96  https://m.media-amazon.com/images/M/MV5BZWZkND...             [nm0001565]
# 97  https://m.media-amazon.com/images/M/MV5BZDRkOD...             [nm0004306]
# 98  https://m.media-amazon.com/images/M/MV5BMTQxNz...  [nm1853544, nm0719208]
# 99  https://m.media-amazon.com/images/M/MV5BODRmMz...  [nm0482670, nm0950707]
#
#                                                actors  \
# 0   [nm0619938, nm0410968, nm0412615, nm0848533, n...
# 1   [nm0000206, nm0000401, nm0005251, nm0915989, n...
# 2   [nm0000434, nm0000148, nm0000402, nm0000027, n...
# 3   [nm0000122, nm0156039, nm5681967, nm0616729, n...
# 4   [nm0000197, nm0001221, nm0077720, nm0110480, n...
# ..                                                ...
# 95  [nm0425005, nm2394794, nm0366389, nm0085312, n...
# 96  [nm0000199, nm0000136, nm0000514, nm0456124, n...
# 97  [nm0362766, nm0000234, nm0396558, nm2368789, n...
# 98  [nm0136797, nm1325419, nm0000973, nm1388927, n...
# 99  [nm0950707, nm0586345, nm0946642, nm0948124, n...
#
#                                        similar_movies         id
# 0   [tt0047478, tt0027977, tt0095765, tt0021749, t...  tt0056058
# 1   [tt0137523, tt0109830, tt1375666, tt0110912, t...  tt0133093
# 2   [tt0080684, tt0086190, tt0121766, tt0120915, t...  tt0076759
# 3   [tt0027977, tt0032553, tt0047396, tt0056058, t...  tt0021749
# 4   [tt0102926, tt0050083, tt0108052, tt0099685, t...  tt0073486
# ..                                                ...        ...
# 95  [tt7975244, tt1489889, tt7991608, tt1270797, t...  tt2283362
# 96  [tt0106519, tt1302006, tt0105323, tt0106489, t...  tt0119008
# 97  [tt12037194, tt3315342, tt0325980, tt7286456, ...  tt1392190
# 98  [tt1323594, tt3469046, tt2293640, tt7510222, t...  tt1690953
# 99  [tt0092254, tt0098971, tt0081499, tt0085953, t...  tt0093367
#
# [100 rows x 12 columns]
